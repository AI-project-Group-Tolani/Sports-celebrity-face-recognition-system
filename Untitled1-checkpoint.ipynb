# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv2.imread('OIP.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (710, 474, 3)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (710, 474)

# %%
gray
# Out:
# array([[251, 248, 246, ..., 243, 250, 250],
#        [248, 245, 243, ..., 241, 248, 248],
#        [245, 243, 240, ..., 238, 245, 245],
#        ...,
#        [ 32,  17,  16, ..., 139, 140, 140],
#        [ 50,  26,  17, ..., 142, 143, 143],
#        [ 62,  31,  16, ..., 144, 145, 145]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
import cv2

face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

# Load an image and convert it to grayscale
img = cv2.imread('OIP.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)
print(faces)
faces
# Out:
# [[ 89 114 218 218]]
# array([[ 89, 114, 218, 218]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (89, 114, 218, 218)

# %%
face_OIP =cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_OIP)

# %%
cv2.destroyAllWindows()
for (x,y,w, h) in faces:
        face_OIP = cv2.rectangle (img, (x,y),(x+w, y+h), (255,0,0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color=  face_OIP[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex, ey, ew, eh) in eyes:
                cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255,0), 2)
                
                
plt.figure()
plt.imshow (face_OIP, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes ('OIP.jpg'):
        OIP cv2.imread ('OIP.jpg')
        gray = cv2.cvt Color (img, cv2.COLOR_BGR2GRAY)
        faces=face_cascade.detectMultiScale (gray, 1.3, 5)
        for (x,y,w, h) in faces:
                roi_gray = gray [y:y+h, x:x+w]
                roi_color = OIP [y:y+h, x:x+w]
                eyes = eye_cascade.detectMultiscale(roi_gray)
                if len (eyes) >= 2:
                            return roi_color
# Out:
#   Cell In[22], line 1
#     def get_cropped_image_if_2_eyes ('OIP.jpg'):
#                                      ^
# SyntaxError: invalid syntax

# %%
original_image = cv2.imread('OIP.jpg')
plt.imshow (original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('OIP.jpg')
plt.imshow (cropped_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cropped_image = get_cropped_image_if_2_eyes('OIP.jpg')
#       2 plt.imshow (cropped_image)
#
# NameError: name 'get_cropped_image_if_2_eyes' is not defined
